# %%
import cv2 as cv
from google.colab import files
from google.colab.patches import cv2_imshow

print('Hello World')

#!rm *.jpg
#!ls
# Out:
# Hello World

# %%
uploaded = files.upload()

img1_rgb = cv.imread('Lenna.jpg') 

cv2_imshow(img1_rgb)
# Out:
#      <input type="file" id="files-0e906271-55f9-40af-b408-07e683ed65db" name="files[]" multiple disabled />
#      <output id="result-0e906271-55f9-40af-b408-07e683ed65db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Lenna.jpg to Lenna.jpg
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45290BDDA0>
